# %%
import matplotlib as mpl
import matplotlib.patches as patches
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\Admin\HC3 EDA\GriD\all_words4.csv")

# %%
df
# Out:
#        Unnamed: 0         word  count
# 0               0          and  23803
# 1               1          can   9330
# 2               2         with   4857
# 3               3         have   3829
# 4               4           or   3417
# ...           ...          ...    ...
# 12756       12756  trafficking      1
# 12757       12757    waitstaff      1
# 12758       12758       hourly      1
# 12759       12759  expectation      1
# 12760       12760         tips      1
#
# [12761 rows x 3 columns]

# %%
# Create a matplotlib table
plt.figure(figsize=(12, 6))
table = plt.table(cellText=df.values,
                  colLabels=df.columns,
                  cellLoc='center',
                  loc='upper left')

# Style the table
table.auto_set_font_size(False)
table.set_fontsize(12)
table.scale(1.2, 1.2)

# Remove axis
plt.axis('off')

# Add title
plt.title("Word Count Statistics", fontsize=16, fontweight='bold')

# Show the table
plt.show()
# Out:
# c:\Users\Admin\HC3 EDA\.venv\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 12471 (\N{KATAKANA LETTER SI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\Admin\HC3 EDA\.venv\Lib\site-packages\IPython\core\formatters.py:343, in BaseFormatter.__call__(self, obj)
#     341     pass
#     342 else:
# --> 343     return printer(obj)
#     344 # Finally look for special method names
#     345 method = get_real_method(obj, self.print_method)
#
# File c:\Users\Admin\HC3 EDA\.venv\Lib\site-packages\IPython\core\pylabtools.py:152, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     149     from matplotlib.backend_bases import FigureCanvasBase
#     150     FigureCanvasBase(fig)
# --> 152 fig.canvas.print_figure(bytes_io, **kw)
#     153 data = bytes_io.getvalue()
# ...

# %%
# Create a matplotlib table with the test data
plt.figure(figsize=(8, 4))
table = plt.table(cellText=df.values,
                  colLabels=df.columns,
                  cellLoc='center',
                  loc='upper left')

# Style the table
table.auto_set_font_size(False)
table.set_fontsize(12)
table.scale(1.2, 1.2)

# Remove axis
plt.axis('off')

# Calculate the figure size and the number of rows in the table
fig_size = plt.gcf().get_size_inches()
num_rows = len(df)

# Calculate the height of the figure in pixels
fig_height_pixels = fig_size[1] * plt.gcf().dpi

# Calculate the approximate number of pixels per row
pixels_per_row = fig_height_pixels / num_rows

print(f"Approximate number of pixels per row: {pixels_per_row:.2f}")

# Show the table
plt.show()
# Out:
# Approximate number of pixels per row: 0.03
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\Admin\HC3 EDA\.venv\Lib\site-packages\IPython\core\formatters.py:343, in BaseFormatter.__call__(self, obj)
#     341     pass
#     342 else:
# --> 343     return printer(obj)
#     344 # Finally look for special method names
#     345 method = get_real_method(obj, self.print_method)
#
# File c:\Users\Admin\HC3 EDA\.venv\Lib\site-packages\IPython\core\pylabtools.py:152, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     149     from matplotlib.backend_bases import FigureCanvasBase
#     150     FigureCanvasBase(fig)
# --> 152 fig.canvas.print_figure(bytes_io, **kw)
#     153 data = bytes_io.getvalue()
#     154 if fmt == 'svg':
#
# ...

# %%
# Create a matplotlib table
plt.figure(figsize=(20, 10))  # Adjust the figure size as needed
table = plt.table(cellText=df.values,
                  colLabels=df.columns,
                  cellLoc='center',
                  loc='upper left')

# Style the table
table.auto_set_font_size(False)
table.set_fontsize(10)  # Adjust the font size as needed
table.scale(1.5, 1.5)    # Adjust the scaling as needed

# Remove axis
plt.axis('off')

# Add title
plt.title("Word Counts", fontsize=20, fontweight='bold')

# Save the table as an image file
plt.savefig('table_chart_large.png', bbox_inches='tight', pad_inches=0.1)

# Show confirmation message
print("Table chart saved as 'table_chart_large.png'")

# Close the plot
plt.close()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_29968\1432293375.py:20: UserWarning: Glyph 12471 (\N{KATAKANA LETTER SI}) missing from current font.
#   plt.savefig('table_chart_large.png', bbox_inches='tight', pad_inches=0.1)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 20
#      17 plt.title("Word Counts", fontsize=20, fontweight='bold')
#      19 # Save the table as an image file
# ---> 20 plt.savefig('table_chart_large.png', bbox_inches='tight', pad_inches=0.1)
#      22 # Show confirmation message
#      23 print("Table chart saved as 'table_chart_large.png'")
#
# File c:\Users\Admin\HC3 EDA\.venv\Lib\site-packages\matplotlib\pyplot.py:1134, in savefig(*args, **kwargs)
#    1131 fig = gcf()
#    1132 # savefig default implementation has no return, so mypy is unhappy
#    1133 # presumably this is here because subclasses can return?
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Sample DataFrame
data = {
    'City': ['New York', 'Los Angeles', 'Chicago', 'Houston', 'Phoenix'],
    'Population (millions)': [8.4, 3.9, 2.7, 2.3, 1.7],
    'Area (sq miles)': [468.9, 469.3, 227.3, 637.5, 517.6]
}
df = pd.DataFrame(data)

# Convert DataFrame to a list of lists
data_values = [df.columns.tolist()] + df.values.tolist()

# Create a matplotlib table
plt.figure(figsize=(8, 4))
table = plt.table(cellText=data_values,
                  colLabels=df.columns,
                  cellLoc='center',
                  loc='upper left')

# Style the table
table.auto_set_font_size(False)
table.set_fontsize(12)
table.scale(1.2, 1.2)

# Remove axis
plt.axis('off')

# Add title
plt.title("City Statistics", fontsize=16, fontweight='bold')

# Show the table
plt.show()
